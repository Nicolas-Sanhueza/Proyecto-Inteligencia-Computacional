# %% [markdown]
# # Proyecto Inteligencia Computacional

# %%
import pandas as pd 
import numpy as np
import pyarrow.parquet as pq
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

feats = pd.read_parquet('./data/features.parquet') 
lcs = pd.read_parquet('./data/lcs.parquet') 
oids = pd.read_parquet('./data/oids.parquet')

# %%
# DataFrame con todas las features de cada objeto + la clase a la que pertenecen
df_feats_class = pd.merge(oids, feats, how="inner", on="oid", sort=True)

# %% [markdown]
# #### Reemplazo de NaN por la Media de la característica correspondiente

# %%
from sklearn.impute import SimpleImputer

# Seleccionamos sólo columnas numéricas
numerical_cols = df_feats_class.select_dtypes(include=['float64', 'int64']).columns
imputer = SimpleImputer(strategy='mean')    
imputed_numerical_data = imputer.fit_transform(df_feats_class[numerical_cols])
imputed_numerical_df = pd.DataFrame(imputed_numerical_data, columns=numerical_cols)

# Columnas no numéricas
categorical_cols = df_feats_class.select_dtypes(exclude=['float64', 'int64']).columns
# Combinar columnas
imputed_df_feats_class = pd.concat([df_feats_class[categorical_cols].reset_index(drop=True), imputed_numerical_df], axis=1)    # DF SIN VALORES NaN!
imputed_df_feats_class
# Out:
#                oid alerceclass     Q31_r     Rcs_r    Skew_r  SmallKurtosis_r  \
# 0     ZTF17aaaaafz         LPV  1.464396  0.215017 -0.173195        -0.741959
# 1     ZTF17aaaaajg         RRL  0.366083  0.104706  0.405444        -1.552645
# 2     ZTF17aaaaavq         LPV  2.839326  0.314243  0.001261        -1.538020
# 3     ZTF17aaaacth          EB  0.029942  0.087856  2.875995         8.698949
# 4     ZTF17aaaadmx         LPV  1.512813  0.298351 -0.484697        -0.732266
# ...            ...         ...       ...       ...       ...              ...
# 8414  ZTF21abblixa         CEP  0.386163  0.168959  0.047430         0.281581
# 8415  ZTF21abbvvji         RRL  0.389800  0.259549  0.506888        -1.274300
# 8416  ZTF21abbzxoh        DSCT  0.457832  0.359654  0.324823        -1.448713
# 8417  ZTF21abcgftb         RRL  0.347692  0.136953  0.130523        -0.614194
# 8418  ZTF21abeyrsz         RRL  0.373502  0.294810 -0.334165        -1.277825
#
#          Std_r  StetsonK_r   Pvar_r  ExcessVar_r  ...  \
# 0     0.976239    0.900859  1.00000     0.002542  ...
# 1     0.192603    0.883649  1.00000     0.000132  ...
# 2     1.494441    0.800329  1.00000     0.009013  ...
# 3     0.476514    0.543303  1.00000     0.000773  ...
# 4     1.037921    0.791008  1.00000     0.004826  ...
# ...        ...         ...      ...          ...  ...
# 8414  0.253389    0.814502  0.99308     0.000478  ...
# 8415  0.202627    0.925235  1.00000     0.000000  ...
# 8416  0.219106    0.893713  1.00000     0.000203  ...
# 8417  0.192589    0.830999  1.00000     0.000217  ...
# 8418  0.209527    0.926331  1.00000     0.000170  ...
#
#       max_diffmaglim_after_fid_g  median_diffmaglim_after_fid_g  \
# 0                      20.823200                      19.508801
# 1                      21.066299                      20.175400
# 2                      21.126600                      20.008301
# 3                      20.865801                      19.922400
# 4                      20.916500                      19.762699
# ...                          ...                            ...
# 8414                   20.019199                      19.309700
# 8415                   20.693900                      20.560050
# 8416                   20.815800                      20.049101
# 8417                   20.883900                      20.081400
# 8418                   20.580000                      19.902400
#
#       delta_mag_fid_r  delta_mjd_fid_r  first_mag_r  mean_mag_r  min_mag_r  \
# 0            4.200617      1339.718634    17.564814   18.677803  16.661703
# 1            0.580561      1251.693287    16.485819   16.641393  16.403305
# 2            5.057098      1434.977350    16.880259   15.694755  13.155277
# 3            2.519390      1189.854849    16.813747   17.039993  16.799618
# 4            5.000990      1338.672627    13.901798   14.856612  12.674696
# ...               ...              ...          ...         ...        ...
# 8414         0.926920      1243.084857    15.423586   15.427888  14.980499
# 8415         0.483679        28.936458    16.840920   17.002280  16.805649
# 8416         0.595043       353.070185    15.650616   15.353477  15.068784
# 8417         0.794328       375.932407    13.234352   13.045922  12.675948
# 8418         0.557045        57.970718    16.220362   16.009310  15.695902
#
#          n_det_r  PercentAmplitude_r  Harmonics_mag_5_r
# 0     628.000000            0.112910       2.703024e-01
# 1     320.000000            0.027691       9.082992e-03
# 2     656.000000            0.180732       1.054833e-01
# 3      93.000000            0.145533       2.831434e-02
# 4     479.000000            0.172507       9.711672e-02
# ...          ...                 ...                ...
# 8414  175.867977            0.043515       3.447564e+08
# 8415    8.000000            0.024969       3.964182e+00
# 8416   24.000000            0.024223       2.072808e+00
# 8417   24.000000            0.034678       2.242692e-02
# 8418   11.000000            0.026999       1.833439e+00
#
# [8419 rows x 180 columns]

# %% [markdown]
# ## Versión Actual

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
# DataFrame con todas las features de cada objeto + la clase a la que pertenecen
df_feats_class = pd.merge(oids, feats, how="inner", on="oid", sort=True)
df_feats_for_forest = df_feats_class[df_feats_class.columns[1:]]
arr_class = df_feats_for_forest[df_feats_for_forest.columns[0]].values
df_feats_for_forest
# Out:
#      alerceclass     Q31_r     Rcs_r    Skew_r  SmallKurtosis_r     Std_r  \
# 0            LPV  1.464396  0.215017 -0.173195        -0.741959  0.976239
# 1            RRL  0.366083  0.104706  0.405444        -1.552645  0.192603
# 2            LPV  2.839326  0.314243  0.001261        -1.538020  1.494441
# 3             EB  0.029942  0.087856  2.875995         8.698949  0.476514
# 4            LPV  1.512813  0.298351 -0.484697        -0.732266  1.037921
# ...          ...       ...       ...       ...              ...       ...
# 8414         CEP       NaN       NaN       NaN              NaN       NaN
# 8415         RRL  0.389800  0.259549  0.506888        -1.274300  0.202627
# 8416        DSCT  0.457832  0.359654  0.324823        -1.448713  0.219106
# 8417         RRL  0.347692  0.136953  0.130523        -0.614194  0.192589
# 8418         RRL  0.373502  0.294810 -0.334165        -1.277825  0.209527
#
#       StetsonK_r  Pvar_r  ExcessVar_r  PairSlopeTrend_r  ...  \
# 0       0.900859     1.0     0.002542          0.033333  ...
# 1       0.883649     1.0     0.000132         -0.100000  ...
# 2       0.800329     1.0     0.009013          0.300000  ...
# 3       0.543303     1.0     0.000773          0.033333  ...
# 4       0.791008     1.0     0.004826         -0.233333  ...
# ...          ...     ...          ...               ...  ...
# 8414         NaN     NaN          NaN               NaN  ...
# 8415    0.925235     1.0     0.000000          0.033333  ...
# 8416    0.893713     1.0     0.000203         -0.100000  ...
# 8417    0.830999     1.0     0.000217          0.100000  ...
# 8418    0.926331     1.0     0.000170         -0.066667  ...
#
#       max_diffmaglim_after_fid_g  median_diffmaglim_after_fid_g  \
# 0                      20.823200                      19.508801
# 1                      21.066299                      20.175400
# 2                      21.126600                      20.008301
# 3                      20.865801                      19.922400
# 4                      20.916500                      19.762699
# ...                          ...                            ...
# 8414                   20.019199                      19.309700
# 8415                   20.693900                      20.560050
# 8416                   20.815800                      20.049101
# 8417                   20.883900                      20.081400
# 8418                   20.580000                      19.902400
#
#       delta_mag_fid_r  delta_mjd_fid_r  first_mag_r  mean_mag_r  min_mag_r  \
# 0            4.200617      1339.718634    17.564814   18.677803  16.661703
# 1            0.580561      1251.693287    16.485819   16.641393  16.403305
# 2            5.057098      1434.977350    16.880259   15.694755  13.155277
# 3            2.519390      1189.854849    16.813747   17.039993  16.799618
# 4            5.000990      1338.672627    13.901798   14.856612  12.674696
# ...               ...              ...          ...         ...        ...
# 8414              NaN              NaN          NaN         NaN        NaN
# 8415         0.483679        28.936458    16.840920   17.002280  16.805649
# 8416         0.595043       353.070185    15.650616   15.353477  15.068784
# 8417         0.794328       375.932407    13.234352   13.045922  12.675948
# 8418         0.557045        57.970718    16.220362   16.009310  15.695902
#
#       n_det_r  PercentAmplitude_r  Harmonics_mag_5_r
# 0       628.0            0.112910           0.270302
# 1       320.0            0.027691           0.009083
# 2       656.0            0.180732           0.105483
# 3        93.0            0.145533           0.028314
# 4       479.0            0.172507           0.097117
# ...       ...                 ...                ...
# 8414      NaN                 NaN                NaN
# 8415      8.0            0.024969           3.964182
# 8416     24.0            0.024223           2.072808
# 8417     24.0            0.034678           0.022427
# 8418     11.0            0.026999           1.833439
#
# [8419 rows x 179 columns]

# %%
# Suponiendo que 'feats' es tu DataFrame y 'target' es la columna de etiquetas
X_forest = df_feats_for_forest.drop(columns=['alerceclass'])  # Reemplaza 'target' con el nombre de tu columna de etiquetas
y_forest = df_feats_for_forest['alerceclass']  # Reemplaza 'target' con el nombre de tu columna de etiquetas

# Entrenar el modelo RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, 
                            criterion="gini",
                            max_features="sqrt",
                            bootstrap=True,
                            max_samples=2/3,
                            oob_score=True,
                            random_state=42
                            ,class_weight="balanced")
clf.fit(X_forest, y_forest)

# Obtener la importancia de las características
feature_importances = clf.feature_importances_

# Crear un DataFrame para visualizar la importancia de las características
importance_df = pd.DataFrame({
    'Feature': X_forest.columns,
    'Importance': feature_importances
})

# Ordenar el DataFrame por importancia
importance_df = importance_df.sort_values(by='Importance', ascending=False)
importance_df
# Out:
#                   Feature  Importance
# 115  Multiband_period_g_r    0.077157
# 117         Period_band_g    0.061812
# 119         Period_band_r    0.056347
# 48           g-r_mean_g_r    0.033195
# 49       g-r_max_corr_g_r    0.031238
# ..                    ...         ...
# 27         SPM_tau_rise_r    0.000592
# 56         MHPS_PN_flag_g    0.000365
# 76                 Pvar_g    0.000180
# 6                  Pvar_r    0.000152
# 61         MHPS_PN_flag_r    0.000116
#
# [178 rows x 2 columns]

# %% [markdown]
# # Upsampleo de clases

# %%
from sklearn.utils import resample
from sklearn.utils import shuffle

# Supongamos que df_feats_for_forest es tu DataFrame y 'alerceclass' es la columna de clases
class_counts = df_feats_for_forest['alerceclass'].value_counts()
max_class_count = class_counts.max()

# Crear un nuevo DataFrame vacío para los datos sobremuestreados
df_upsampled = pd.DataFrame()

for class_label in class_counts.index:
    df_class = df_feats_for_forest[df_feats_for_forest['alerceclass'] == class_label]
    # Sobremuestreo
    df_class_upsampled = resample(df_class, 
                                  replace=True,  # Muestreo con reemplazo
                                  n_samples=max_class_count,  # Número de muestras igual a la clase mayoritaria
                                  random_state=42)
    df_upsampled = pd.concat([df_upsampled, df_class_upsampled], axis=0)

# Mezclar los datos para evitar cualquier orden residual
df_upsampled = shuffle(df_upsampled, random_state=42)
df_upsampled
df_upsampled['alerceclass'].value_counts()
# Out:
# alerceclass
# CEP     2689
# DSCT    2689
# LPV     2689
# EB      2689
# RRL     2689
# Name: count, dtype: int64

# %%
importance_df_ = importance_df[importance_df.columns[:-1]].head(100)
importance_arr = importance_df_["Feature"].values

df_feats_for_auto = df_upsampled[importance_arr]
df_feats_for_auto
# Out:
#       Period_band_g  Multiband_period_g_r  Period_band_r  g-r_mean_g_r  \
# 830        0.595369              0.595369       0.595369      0.196394
# 7842       0.131250              0.131250       0.131250      0.353990
# 2538       0.997951              0.997951       0.499500      1.807448
# 136      246.753248            246.753248     246.753248      1.713871
# 6594       0.711770              0.711770       0.711770      0.342292
# ...             ...                   ...            ...           ...
# 2604       0.501889              0.501889       0.501889     -0.398334
# 2967       0.119456              0.119456            NaN           NaN
# 4865       1.033845              1.033845            NaN           NaN
# 185        0.197631              0.197631       0.197631      0.701314
# 4840     379.999984            379.999984     379.999984      2.168858
#
#       g-r_max_corr_g_r       g-W2  g-r_max_g_r  g-r_mean_corr_g_r  \
# 830           0.386225   2.325885     0.092970           0.581688
# 7842          0.316222        NaN    -0.237152           0.480149
# 2538          1.879362   9.406768     1.474511           2.047141
# 136           1.345716   9.793159     1.314535           1.740632
# 6594          0.098091   1.317976     0.104615          -0.022948
# ...                ...        ...          ...                ...
# 2604         -0.262184   0.858356    -0.610697           0.178446
# 2967               NaN   1.761375          NaN                NaN
# 4865               NaN   7.397063          NaN                NaN
# 185           0.679770   2.538471     0.663917           0.601101
# 4840          1.578634  11.932949     1.569443           2.304528
#
#       GP_DRW_tau_g  Autocor_length_r  ...  Harmonics_mag_1_r  MedianAbsDev_r  \
# 830       0.306396               1.0  ...           0.201877        0.110612
# 7842      0.068272               1.0  ...       20753.920506        0.044712
# 2538    196.185887              42.0  ...           0.160375        0.122696
# 136     716.416690              20.0  ...           2.174813        0.957532
# 6594      0.276249               1.0  ...           0.391638        0.111017
# ...            ...               ...  ...                ...             ...
# 2604      0.810944               8.0  ...           0.338399        0.081285
# 2967      2.203885               NaN  ...                NaN             NaN
# 4865      0.014402               NaN  ...                NaN             NaN
# 185       0.135534               2.0  ...           0.280875        0.255279
# 4840    650.974668              15.0  ...           1.973927        0.922623
#
#       Harmonics_phase_3_g  Psi_CS_r  Beyond1Std_r  sgscore1     SPM_chi_g  \
# 830              4.147487  0.292068      0.422131  0.982929     86.200571
# 7842             4.311353  0.417353      0.235294  0.843500    234.968346
# 2538             0.649412  0.248148      0.436508  1.000000     80.648103
# 136              3.700069  0.243928      0.423221  0.500000  29215.004927
# 6594             0.501424  0.456087      0.384615  1.000000    889.600757
# ...                   ...       ...           ...       ...           ...
# 2604             4.632779  0.270117      0.393728  1.000000     66.922035
# 2967             3.320266       NaN           NaN  0.500000    832.349747
# 4865             5.311938       NaN           NaN  0.500000   2537.097262
# 185              6.059648  0.302886      0.377016  0.993125    138.752427
# 4840             5.891966  0.290492      0.422492  0.500000  49506.579555
#
#       Meanvariance_r  delta_mjd_fid_g  MHPS_low_g
# 830         0.013231      1389.053345    0.357697
# 7842        0.011791      1132.915150    0.403663
# 2538        0.014381      1473.006447    0.765489
# 136         0.084965      1439.040833   32.561378
# 6594        0.024440      1256.790949    0.392452
# ...              ...              ...         ...
# 2604        0.018750      1436.067905    5.512213
# 2967             NaN      1382.015139    0.069190
# 4865             NaN      1241.297593    0.037510
# 185         0.016532      1352.120856    0.183674
# 4840        0.089842      1409.021956   65.484573
#
# [13445 rows x 100 columns]

# %% [markdown]
# # Reemplazo de Nan

# %%
from sklearn.impute import SimpleImputer

# Seleccionamos sólo columnas numéricas
numerical_cols = df_feats_for_auto.columns
imputer = SimpleImputer(strategy='most_frequent')    
imputed_numerical_data = imputer.fit_transform(df_feats_for_auto[numerical_cols])
imputed_numerical_df = pd.DataFrame(imputed_numerical_data, columns=numerical_cols)
imputed_numerical_df
# Out:
#        Period_band_g  Multiband_period_g_r  Period_band_r  g-r_mean_g_r  \
# 0           0.595369              0.595369       0.595369      0.196394
# 1           0.131250              0.131250       0.131250      0.353990
# 2           0.997951              0.997951       0.499500      1.807448
# 3         246.753248            246.753248     246.753248      1.713871
# 4           0.711770              0.711770       0.711770      0.342292
# ...              ...                   ...            ...           ...
# 13440       0.501889              0.501889       0.501889     -0.398334
# 13441       0.119456              0.119456     999.999953     -0.260430
# 13442       1.033845              1.033845     999.999953     -0.260430
# 13443       0.197631              0.197631       0.197631      0.701314
# 13444     379.999984            379.999984     379.999984      2.168858
#
#        g-r_max_corr_g_r       g-W2  g-r_max_g_r  g-r_mean_corr_g_r  \
# 0              0.386225   2.325885     0.092970           0.581688
# 1              0.316222   0.973805    -0.237152           0.480149
# 2              1.879362   9.406768     1.474511           2.047141
# 3              1.345716   9.793159     1.314535           1.740632
# 4              0.098091   1.317976     0.104615          -0.022948
# ...                 ...        ...          ...                ...
# 13440         -0.262184   0.858356    -0.610697           0.178446
# 13441         -0.185009   1.761375    -0.310000          -0.031787
# 13442         -0.185009   7.397063    -0.310000          -0.031787
# 13443          0.679770   2.538471     0.663917           0.601101
# 13444          1.578634  11.932949     1.569443           2.304528
#
#        GP_DRW_tau_g  Autocor_length_r  ...  Harmonics_mag_1_r  MedianAbsDev_r  \
# 0          0.306396               1.0  ...           0.201877        0.110612
# 1          0.068272               1.0  ...       20753.920506        0.044712
# 2        196.185887              42.0  ...           0.160375        0.122696
# 3        716.416690              20.0  ...           2.174813        0.957532
# 4          0.276249               1.0  ...           0.391638        0.111017
# ...             ...               ...  ...                ...             ...
# 13440      0.810944               8.0  ...           0.338399        0.081285
# 13441      2.203885               1.0  ...           0.177309        0.027106
# 13442      0.014402               1.0  ...           0.177309        0.027106
# 13443      0.135534               2.0  ...           0.280875        0.255279
# 13444    650.974668              15.0  ...           1.973927        0.922623
#
#        Harmonics_phase_3_g  Psi_CS_r  Beyond1Std_r  sgscore1     SPM_chi_g  \
# 0                 4.147487  0.292068      0.422131  0.982929     86.200571
# 1                 4.311353  0.417353      0.235294  0.843500    234.968346
# 2                 0.649412  0.248148      0.436508  1.000000     80.648103
# 3                 3.700069  0.243928      0.423221  0.500000  29215.004927
# 4                 0.501424  0.456087      0.384615  1.000000    889.600757
# ...                    ...       ...           ...       ...           ...
# 13440             4.632779  0.270117      0.393728  1.000000     66.922035
# 13441             3.320266  0.500000      0.333333  0.500000    832.349747
# 13442             5.311938  0.500000      0.333333  0.500000   2537.097262
# 13443             6.059648  0.302886      0.377016  0.993125    138.752427
# 13444             5.891966  0.290492      0.422492  0.500000  49506.579555
#
#        Meanvariance_r  delta_mjd_fid_g  MHPS_low_g
# 0            0.013231      1389.053345    0.357697
# 1            0.011791      1132.915150    0.403663
# 2            0.014381      1473.006447    0.765489
# 3            0.084965      1439.040833   32.561378
# 4            0.024440      1256.790949    0.392452
# ...               ...              ...         ...
# 13440        0.018750      1436.067905    5.512213
# 13441        0.003570      1382.015139    0.069190
# 13442        0.003570      1241.297593    0.037510
# 13443        0.016532      1352.120856    0.183674
# 13444        0.089842      1409.021956   65.484573
#
# [13445 rows x 100 columns]

# %%
# Normalización datos
cols = imputed_numerical_df.columns
scaled_numerical_data = StandardScaler().fit_transform(imputed_numerical_df)
scaled_numerical_df = pd.DataFrame(scaled_numerical_data, columns=cols)
scaled_numerical_df.insert(0, "alerceclass", df_upsampled['alerceclass'].values)
scaled_numerical_df
# Out:
#       alerceclass  Period_band_g  Multiband_period_g_r  Period_band_r  \
# 0             CEP      -0.375201             -0.326095      -0.440782
# 1            DSCT      -0.376873             -0.330686      -0.442224
# 2             LPV      -0.373750             -0.322113      -0.441080
# 3             LPV       0.512025              2.108931       0.324178
# 4              EB      -0.374781             -0.324944      -0.440420
# ...           ...            ...                   ...            ...
# 13440         RRL      -0.375538             -0.327020      -0.441072
# 13441        DSCT      -0.376916             -0.330803       2.664966
# 13442         LPV      -0.373620             -0.321758       2.664966
# 13443          EB      -0.376634             -0.330030      -0.442018
# 13444         LPV       0.992285              3.427026       0.738255
#
#        g-r_mean_g_r  g-r_max_corr_g_r      g-W2  g-r_max_g_r  \
# 0         -0.411294         -0.287998 -0.350728    -0.395601
# 1         -0.239294         -0.360049 -0.711577    -0.718541
# 2          1.347005          1.248833  1.539050     0.955884
# 3          1.244875          0.699571  1.642172     0.799388
# 4         -0.252062         -0.584564 -0.619723    -0.384209
# ...             ...               ...       ...          ...
# 13440     -1.060379         -0.955382 -0.742389    -1.083959
# 13441     -0.909871         -0.875948 -0.501387    -0.789804
# 13442     -0.909871         -0.875948  1.002691    -0.789804
# 13443      0.139774          0.014136 -0.293992     0.162924
# 13444      1.741448          0.939305  2.213249     1.048750
#
#        g-r_mean_corr_g_r  GP_DRW_tau_g  ...  Harmonics_mag_1_r  \
# 0              -0.215021     -0.010223  ...          -0.019865
# 1              -0.321585     -0.010223  ...          -0.019865
# 2               1.322964     -0.010223  ...          -0.019865
# 3               1.001285     -0.010222  ...          -0.019865
# 4              -0.849582     -0.010223  ...          -0.019865
# ...                  ...           ...  ...                ...
# 13440          -0.638220     -0.010223  ...          -0.019865
# 13441          -0.858859     -0.010223  ...          -0.019865
# 13442          -0.858859     -0.010223  ...          -0.019865
# 13443          -0.194647     -0.010223  ...          -0.019865
# 13444           1.593092     -0.010222  ...          -0.019865
#
#        MedianAbsDev_r  Harmonics_phase_3_g  Psi_CS_r  Beyond1Std_r  sgscore1  \
# 0           -0.098214             0.458131 -0.098021      0.638825  0.466090
# 1           -0.452219             0.542438  1.284624     -1.156186 -0.314169
# 2           -0.033298            -1.341588 -0.582731      0.776949  0.561621
# 3            4.451327             0.227940 -0.629302      0.649296 -2.236431
# 4           -0.096036            -1.417726  1.712094      0.278398  0.561621
# ...               ...                  ...       ...           ...       ...
# 13440       -0.255751             0.707808 -0.340281      0.365948  0.561621
# 13441       -0.546795             0.032535  2.196721     -0.214287 -2.236431
# 13442       -0.546795             1.057227  2.196721     -0.214287 -2.236431
# 13443        0.678916             1.441916  0.021359      0.205389  0.523148
# 13444        4.263799             1.355645 -0.115416      0.642296 -2.236431
#
#        SPM_chi_g  Meanvariance_r  delta_mjd_fid_g  MHPS_low_g
# 0      -0.082119       -0.120795         0.625216   -0.181997
# 1      -0.078357       -0.211306         0.015715   -0.177440
# 2      -0.082260       -0.048512         0.824989   -0.141574
# 3       0.654538        4.387382         0.744165    3.010185
# 4      -0.061802        0.583649         0.310487   -0.178552
# ...          ...             ...              ...         ...
# 13440  -0.082607        0.226053         0.737091    0.328944
# 13441  -0.063249       -0.727972         0.608468   -0.210595
# 13442  -0.020137       -0.727972         0.273619   -0.213735
# 13443  -0.080790        0.086640         0.537332   -0.199247
# 13444   1.167705        4.693871         0.672733    6.273688
#
# [13445 rows x 101 columns]

# %%
X = scaled_numerical_df.drop(columns=['alerceclass']) 
y = scaled_numerical_df['alerceclass'] 

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# # Act MTP2

# %%
importance_df_ = importance_df[importance_df.columns[:-1]].head(100)
importance_arr = importance_df_["Feature"].values

df_feats_for_auto = df_feats_for_forest[importance_arr]
df_feats_for_auto.insert(0, "alerceclass", df_feats_for_forest['alerceclass'].values)
df_feats_for_auto['alerceclass'].value_counts()
# Out:
# alerceclass
# EB      2689
# RRL     2652
# LPV     1374
# CEP     1172
# DSCT     532
# Name: count, dtype: int64

# %%
# Extraer 50 filas de df_feats_for_auto para cada clase
df_test = df_feats_for_auto.groupby('alerceclass').apply(lambda x: x.sample(n=60, random_state=42)).reset_index(drop=True)
#Primero definimos un conjunto test balanceado con 50 elementos de cada clase
X_test = df_test.drop(columns=['alerceclass'])
y_test = df_test['alerceclass']

# Eliminar los elementos de df_test de df_feats_for_auto
df_auto=pd.concat([df_feats_for_auto,df_test]).drop_duplicates(keep=False)


#df_test
df_auto['alerceclass'].value_counts()
#df_test['alerceclass'].value_counts()
# Out:
# C:\Users\icali\AppData\Local\Temp\ipykernel_5192\1582086587.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_test = df_feats_for_auto.groupby('alerceclass').apply(lambda x: x.sample(n=60, random_state=42)).reset_index(drop=True)
# alerceclass
# EB      2629
# RRL     2592
# LPV     1314
# CEP     1112
# DSCT     472
# Name: count, dtype: int64

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import resample, shuffle

#Primero definimos un conjunto test balanceado con 50 elementos de cada clase
df_test = df_feats_for_auto.groupby('alerceclass').apply(lambda x: x.sample(n=60, random_state=42)).reset_index(drop=True)
X_test = df_test.drop(columns=['alerceclass'])
y_test = df_test['alerceclass']

# Eliminar los elementos de df_test de df_feats_for_auto
df_auto = pd.concat([df_feats_for_auto,df_test]).drop_duplicates(keep=False)

df_val=df_auto.groupby('alerceclass').apply(lambda x: x.sample(n=100, random_state=42)).reset_index(drop=True)
X_val = df_val.drop(columns=['alerceclass'])
y_val = df_val['alerceclass']

df_train=pd.concat([df_auto,df_val]).drop_duplicates(keep=False)
X_train = df_auto.drop(columns=['alerceclass'])
y_train = df_auto['alerceclass']


#Imputar los NaN por el valor más frecuente en el conjunto de entrenamiento
imputer = SimpleImputer(strategy='most_frequent')
imputed_X_train = imputer.fit_transform(X_train)
imputed_X_val = imputer.transform(X_val)
imputed_X_test = imputer.transform(X_test)

# Normalizar los datos usando las constantes del conjunto de entrenamiento
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(imputed_X_train)
X_val = scaler.transform(imputed_X_val)
X_test = scaler.transform(imputed_X_test)

#Función para realizar upsampling
def upsample_data(X, y):
    df = pd.concat([pd.DataFrame(X), y.reset_index(drop=True)], axis=1)
    class_counts = y.value_counts()
    max_class_count = class_counts.max()
    
    df_upsampled = pd.DataFrame()
    for class_label in class_counts.index:
        df_class = df[df['alerceclass'] == class_label]
        df_class_upsampled = resample(df_class, 
                                      replace=True,  # Muestreo con reemplazo
                                      n_samples=max_class_count,  # Número de muestras igual a la clase mayoritaria
                                      random_state=42)
        df_upsampled = pd.concat([df_upsampled, df_class_upsampled], axis=0)
    
    df_upsampled = shuffle(df_upsampled, random_state=42)
    return df_upsampled.drop(columns=['alerceclass']).values, df_upsampled['alerceclass']

# Realizar upsampling en el conjunto de entrenamiento
X_train, y_train = upsample_data(scaled_X_train, y_train)


# Mostrar los resultados
print("Distribución de clases en el conjunto de entrenamiento:")
print(y_train.value_counts())
print("\nDistribución de clases en el conjunto de validación:")
print(y_val.value_counts())
print("\nDistribución de clases en el conjunto de prueba:")
print(y_test.value_counts())
# Out:
# C:\Users\icali\AppData\Local\Temp\ipykernel_5192\1911761858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_test = df_feats_for_auto.groupby('alerceclass').apply(lambda x: x.sample(n=60, random_state=42)).reset_index(drop=True)
# C:\Users\icali\AppData\Local\Temp\ipykernel_5192\1911761858.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_val=df_auto.groupby('alerceclass').apply(lambda x: x.sample(n=100, random_state=42)).reset_index(drop=True)
# Distribución de clases en el conjunto de entrenamiento:
# alerceclass
# LPV     2629
# CEP     2629
# EB      2629
# RRL     2629
# DSCT    2629
# Name: count, dtype: int64
#
# Distribución de clases en el conjunto de validación:
# alerceclass
# CEP     100
# DSCT    100
# EB      100
# LPV     100
# RRL     100
# Name: count, dtype: int64
#
# Distribución de clases en el conjunto de prueba:
# alerceclass
# CEP     60
# DSCT    60
# EB      60
# LPV     60
# RRL     60
# Name: count, dtype: int64

# %%
from keras.models import Model, load_model, Sequential
from keras.layers import Input, Dense
from keras.callbacks import EarlyStopping
from keras.optimizers import SGD
from keras.optimizers import Adam , Nadam
from keras.optimizers import RMSprop
from keras.layers import Dropout
from torch import nn

dim_entrada = X_train.shape[1]

capa_input = Input(shape=(dim_entrada,))

#CAPAS AUTOENCODER
encoder = Dense(dim_entrada, activation="selu")(capa_input)   
encoder = Dense(60, activation="selu")(encoder)
encoder = Dense(40, activation="selu")(encoder)

encoder = Dense(30, activation="selu")(encoder)  #CUELLO DE BOTELLA

decoder = Dense(40, activation="selu")(encoder)
decoder = Dense(60, activation="selu")(decoder)
decoder = Dense(dim_entrada, activation="selu")(decoder)

#MODELOS
autoencoder = Model(inputs=capa_input, outputs=decoder)
encoder_model = Model(inputs=capa_input, outputs=encoder)


autoencoder.compile(
    loss="mse",
    optimizer=RMSprop(learning_rate=0.001, rho=0.9),
    )

# Extraer los valores de accuracy y loss del historial de entrenamiento
history = autoencoder.fit(
    X_train, 
    X_train,
    epochs=30,
    batch_size=32,
    validation_data=(X_val, X_val),
    callbacks=[EarlyStopping(patience=10)]
)
# Out:
# Epoch 1/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.6479 - val_loss: 0.4125
# Epoch 2/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2850 - val_loss: 0.3499
# Epoch 3/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2559 - val_loss: 0.3457
# Epoch 4/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2249 - val_loss: 0.3037
# Epoch 5/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2054 - val_loss: 0.2935
# Epoch 6/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1957 - val_loss: 0.2918
# Epoch 7/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2000 - val_loss: 0.2874
# Epoch 8/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1952 - val_loss: 0.2753
# Epoch 9/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1730 - val_loss: 0.3078
# Epoch 10/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1648 - val_loss: 0.2725
# Epoch 11/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1888 - val_loss: 0.2903
# Epoch 12/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1836 - val_loss: 0.2594
# Epoch 13/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1659 - val_loss: 0.2539
# Epoch 14/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1504 - val_loss: 0.2528
# Epoch 15/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1477 - val_loss: 0.2472
# Epoch 16/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1656 - val_loss: 0.2550
# Epoch 17/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1503 - val_loss: 0.2556
# Epoch 18/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1342 - val_loss: 0.2458
# Epoch 19/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1867 - val_loss: 0.2416
# Epoch 20/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1499 - val_loss: 0.2423
# Epoch 21/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1434 - val_loss: 0.2483
# Epoch 22/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1640 - val_loss: 0.2433
# Epoch 23/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1410 - val_loss: 0.2564
# Epoch 24/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1533 - val_loss: 0.2364
# Epoch 25/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1786 - val_loss: 0.2377
# Epoch 26/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1410 - val_loss: 0.2293
# Epoch 27/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1398 - val_loss: 0.2280
# Epoch 28/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1473 - val_loss: 0.2137
# Epoch 29/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1305 - val_loss: 0.2122
# Epoch 30/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1251 - val_loss: 0.1962

# %%
# Calcular el error de reconstrucción
from sklearn.metrics import mean_squared_error, mean_absolute_error
reconstructed_X_test = autoencoder.predict(X_test)


test_mse = np.mean(np.square(X_test - reconstructed_X_test), axis=1)


print("Test MSE: ", np.mean(test_mse))


# Graficar los valores de loss
plt.figure(figsize=(12, 5))

# Graficar el loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

mse_per_sample = mean_squared_error(X_test, reconstructed_X_test, multioutput='raw_values')

plt.figure(figsize=(8, 6))
plt.hist(mse_per_sample, bins=50, alpha=0.7, color='b', label='MSE')
plt.xlabel('Reconstruction Error (MSE)')
plt.ylabel('Frequency')
plt.title('Histogram of Reconstruction Errors (MSE)')
plt.grid(True)
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Test MSE:  0.52685986461631

# %% [markdown]
# # Estimation Network

# %%
from keras.models import Model
from keras.layers import Input, Dense
from keras.optimizers import Adam
from keras.utils import to_categorical
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics.pairwise import cosine_distances

# Obtener el vector de embedding del autoencoder
encoded_X_train = encoder_model.predict(X_train)
encoded_X_val = encoder_model.predict(X_val)
encoded_X_test = encoder_model.predict(X_test)

# Convertir las etiquetas a valores numéricos
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_val_encoded = le.transform(y_val)

# Convertir las etiquetas a one-hot encoding
y_train_one_hot = to_categorical(y_train_encoded)
y_val_one_hot = to_categorical(y_val_encoded)

# Definir la red de estimación
input_layer = Input(shape=(encoded_X_train.shape[1],))
hidden_layer = Dense(128, activation='tanh')(input_layer)
#dropout_layer = Dropout(0.2)(hidden_layer)
output_layer = Dense(y_train_one_hot.shape[1], activation='softmax')(hidden_layer)

model_estimation = Model(inputs=input_layer, outputs=output_layer)
model_estimation.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Entrenar la red de estimación
history_estimation = model_estimation.fit(encoded_X_train, 
                                          y_train_one_hot, 
                                          epochs=30,
                                          batch_size=32,
                                          validation_data=(encoded_X_val, y_val_one_hot),
                                          callbacks=[EarlyStopping(patience=10)])
# Out:
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5996 - loss: 0.9975 - val_accuracy: 0.7620 - val_loss: 0.6216
# Epoch 2/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7961 - loss: 0.5563 - val_accuracy: 0.8040 - val_loss: 0.5331
# Epoch 3/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8147 - loss: 0.5018 - val_accuracy: 0.8380 - val_loss: 0.4848
# Epoch 4/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8261 - loss: 0.4720 - val_accuracy: 0.8480 - val_loss: 0.4673
# Epoch 5/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8405 - loss: 0.4408 - val_accuracy: 0.8460 - val_loss: 0.4537
# Epoch 6/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8508 - loss: 0.4229 - val_accuracy: 0.8520 - val_loss: 0.4346
# Epoch 7/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8565 - loss: 0.4070 - val_accuracy: 0.8460 - val_loss: 0.4294
# Epoch 8/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8607 - loss: 0.3810 - val_accuracy: 0.8580 - val_loss: 0.4059
# Epoch 9/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8653 - loss: 0.3725 - val_accuracy: 0.8600 - val_loss: 0.4185
# Epoch 10/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8760 - loss: 0.3543 - val_accuracy: 0.8580 - val_loss: 0.4049
# Epoch 11/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8832 - loss: 0.3308 - val_accuracy: 0.8640 - val_loss: 0.3901
# Epoch 12/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8831 - loss: 0.3275 - val_accuracy: 0.8660 - val_loss: 0.3764
# Epoch 13/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8854 - loss: 0.3282 - val_accuracy: 0.8720 - val_loss: 0.3786
# Epoch 14/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8931 - loss: 0.3119 - val_accuracy: 0.8760 - val_loss: 0.3774
# Epoch 15/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8967 - loss: 0.3064 - val_accuracy: 0.8820 - val_loss: 0.3525
# Epoch 16/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9016 - loss: 0.2808 - val_accuracy: 0.8820 - val_loss: 0.3418
# Epoch 17/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9007 - loss: 0.2845 - val_accuracy: 0.8780 - val_loss: 0.3644
# Epoch 18/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9075 - loss: 0.2734 - val_accuracy: 0.8840 - val_loss: 0.3303
# Epoch 19/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9093 - loss: 0.2575 - val_accuracy: 0.8920 - val_loss: 0.3338
# Epoch 20/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9119 - loss: 0.2506 - val_accuracy: 0.8940 - val_loss: 0.3266
# Epoch 21/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9208 - loss: 0.2476 - val_accuracy: 0.8980 - val_loss: 0.3311
# Epoch 22/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9191 - loss: 0.2426 - val_accuracy: 0.9080 - val_loss: 0.3223
# Epoch 23/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9262 - loss: 0.2284 - val_accuracy: 0.9060 - val_loss: 0.3124
# Epoch 24/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9232 - loss: 0.2287 - val_accuracy: 0.9020 - val_loss: 0.3133
# Epoch 25/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9288 - loss: 0.2100 - val_accuracy: 0.9060 - val_loss: 0.2948
# Epoch 26/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9340 - loss: 0.2097 - val_accuracy: 0.9080 - val_loss: 0.2881
# Epoch 27/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9369 - loss: 0.2036 - val_accuracy: 0.9140 - val_loss: 0.2913
# Epoch 28/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9360 - loss: 0.1926 - val_accuracy: 0.9080 - val_loss: 0.2891
# Epoch 29/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9431 - loss: 0.1850 - val_accuracy: 0.9080 - val_loss: 0.2841
# Epoch 30/30
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9369 - loss: 0.1925 - val_accuracy: 0.9140 - val_loss: 0.2695

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Graficar los valores de loss y accuracy
plt.figure(figsize=(12, 5))

# Graficar el loss
plt.subplot(1, 2, 1)
plt.plot(history_estimation.history['loss'], label='Training Loss')
plt.plot(history_estimation.history['val_loss'], label='Validation Loss')
plt.title('Loss durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Graficar la accuracy
plt.subplot(1, 2, 2)
plt.plot(history_estimation.history['accuracy'], label='Training Accuracy')
plt.plot(history_estimation.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# # GMM

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Obtener las predicciones de la red de estimación
output_estimation_train = model_estimation.predict(encoded_X_train)
output_estimation_val = model_estimation.predict(encoded_X_val)
output_estimation_test = model_estimation.predict(encoded_X_test)

# Definir y entrenar el modelo Deep SVDD
gmm = GaussianMixture(n_components=5, random_state=42)
gmm.fit(output_estimation_train, y_train_encoded)

# Predecir las etiquetas del conjunto de prueba usando Deep SVDD
gmm_labels_test = gmm.predict(output_estimation_test)

# Convertir las etiquetas predichas por Deep SVDD a las etiquetas originales
gmm_labels_test_original = le.inverse_transform(svdd_labels_test)

gmm_accuracy = accuracy_score(y_test, gmm_labels_test_original)
gmm_classification_report = classification_report(y_test, gmm_labels_test_original)

print("Accuracy del GMM: ", gmm_accuracy)
print("Reporte de clasificación del GMM:\n", gmm_classification_report)
# Out:
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy del GMM:  0.8366666666666667
# Reporte de clasificación del GMM:
#                precision    recall  f1-score   support
#
#          CEP       0.84      0.80      0.82        60
#         DSCT       0.82      0.67      0.73        60
#           EB       0.81      0.87      0.84        60
#          LPV       0.92      0.98      0.95        60
#          RRL       0.79      0.87      0.83        60
#
#     accuracy                           0.84       300
#    macro avg       0.84      0.84      0.83       300
# weighted avg       0.84      0.84      0.83       300

# %%
conf_matrix = confusion_matrix(y_test, gmm_labels_test_original)

# Visualizar la matriz de confusión
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Matriz de Confusión usando GMM luego de Estimation Network')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# # MCSVDD

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report

# Obtener las predicciones de la red de estimación
output_estimation_train = model_estimation.predict(encoded_X_train)
output_estimation_val = model_estimation.predict(encoded_X_val)
output_estimation_test = model_estimation.predict(encoded_X_test)

# Definir y entrenar el modelo Deep SVDD
svdd = SVC(kernel='rbf', probability=True, random_state=42)
svdd.fit(output_estimation_train, y_train_encoded)

# Predecir las etiquetas del conjunto de prueba usando Deep SVDD
svdd_labels_test = svdd.predict(output_estimation_test)

# Convertir las etiquetas predichas por Deep SVDD a las etiquetas originales
svdd_labels_test_original = le.inverse_transform(svdd_labels_test)

# Evaluar el rendimiento del modelo Deep SVDD
accuracy_svdd = accuracy_score(y_test, svdd_labels_test_original)
report_svdd = classification_report(y_test, svdd_labels_test_original)

print("Accuracy del modelo Deep SVDD: ", accuracy_svdd)
print("Reporte de clasificación del modelo Deep SVDD:\n", report_svdd)
# Out:
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy del modelo Deep SVDD:  0.8366666666666667
# Reporte de clasificación del modelo Deep SVDD:
#                precision    recall  f1-score   support
#
#          CEP       0.84      0.80      0.82        60
#         DSCT       0.82      0.67      0.73        60
#           EB       0.81      0.87      0.84        60
#          LPV       0.92      0.98      0.95        60
#          RRL       0.79      0.87      0.83        60
#
#     accuracy                           0.84       300
#    macro avg       0.84      0.84      0.83       300
# weighted avg       0.84      0.84      0.83       300

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Crear la matriz de confusión para las etiquetas predichas por mcsvdd
conf_matrix_svdd = confusion_matrix(y_test, svdd_labels_test_original)

# Visualizar la matriz de confusión
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix_svdd, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Matriz de Confusión para mcsvdd')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# # UMAP

# %%
import umap
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# Reducir la dimensionalidad de los datos a 3D usando UMAP
reducer_3d = umap.UMAP(n_components=3, n_neighbors=15, random_state=42)
X_test_3d = reducer_3d.fit_transform(encoded_X_test)

# Graficar los clusters generados por GMM en 3D
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_test_3d[:, 0], X_test_3d[:, 1], X_test_3d[:, 2], c=gmm_labels_test, cmap='viridis', s=50)
legend1 = ax.legend(*scatter.legend_elements(), title="Cluster")
ax.add_artist(legend1)
ax.set_title('Clusters generados por GMM en 3D')
ax.set_xlabel('UMAP Component 1')
ax.set_ylabel('UMAP Component 2')
ax.set_zlabel('UMAP Component 3')
plt.show()

# Graficar los clusters generados por Deep SVDD en 3D
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_test_3d[:, 0], X_test_3d[:, 1], X_test_3d[:, 2], c=svdd_labels_test, cmap='viridis', s=50)
legend1 = ax.legend(*scatter.legend_elements(), title="Cluster")
ax.add_artist(legend1)
ax.set_title('Clusters generados por Deep SVDD en 3D')
ax.set_xlabel('UMAP Component 1')
ax.set_ylabel('UMAP Component 2')
ax.set_zlabel('UMAP Component 3')
plt.show()
# Out:
# c:\anaconda3\envs\inteligencia\Lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#perplexity (30 por defecto): Según la documentación de Scikit-Learn, se recomienda un valor entre 5 y 50 (mayor cuanto mayor sea el dataset), aunque se indica que el algoritmo no es muy sensible a este valor.
# early_exaggeration (12 por defecto): Este parámetro controla la distancia entre bloques semejantes en el espacio final. La elección de este valor no es crítico.
# learning_rate (200 por defecto): Habitualmente en el rango (10-1000). Si es muy elevado, los datos transformados estarán formados por una bola de puntos equidistantes unos de otros. Si es muy bajo, los puntos se mostrarán comprimidos en una densa nube con algunos outliers.
# n_iter (1000 por defecto): Número máximo de iteraciones para la optimización. Debería ser, por lo menos, 250.
# metric: métrica para la medición de las distancias.
# method: algoritmo a usar para el cálculo del gradiente

# Reducir la dimensionalidad de los datos a 3D usando t-SNE
tsne = TSNE(n_components=3, perplexity=5, n_iter=2000, learning_rate=500, random_state=42)
X_test_3d_tsne = tsne.fit_transform(encoded_X_test)

# Graficar los clusters generados por GMM en 3D
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_test_3d_tsne[:, 0], X_test_3d_tsne[:, 1], X_test_3d_tsne[:, 2], c=gmm_labels_test, cmap='viridis', s=50)
legend1 = ax.legend(*scatter.legend_elements(), title="Cluster")
ax.add_artist(legend1)
ax.set_title('Clusters generados por GMM en 3D usando t-SNE')
ax.set_xlabel('t-SNE Component 1')
ax.set_ylabel('t-SNE Component 2')
ax.set_zlabel('t-SNE Component 3')

plt.show()

# Graficar los clusters generados por Deep SVDD en 3D
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_test_3d_tsne[:, 0], X_test_3d_tsne[:, 1], X_test_3d_tsne[:, 2], c=svdd_labels_test, cmap='viridis', s=50)
legend1 = ax.legend(*scatter.legend_elements(), title="Cluster")
ax.add_artist(legend1)
ax.set_title('Clusters generados por Deep SVDD en 3D usando t-SNE')
ax.set_xlabel('t-SNE Component 1')
ax.set_ylabel('t-SNE Component 2')
ax.set_zlabel('t-SNE Component 3')

plt.show()
# Out:
# c:\anaconda3\envs\inteligencia\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
from mpl_toolkits.mplot3d import Axes3D

import matplotlib.pyplot as plt

# Reducir la dimensionalidad de los datos a 3D usando UMAP
reducer_3d = umap.UMAP(n_components=3, n_neighbors=15, random_state=42)
X_test_3d = reducer_3d.fit_transform(encoded_X_test)

# Graficar los clusters generados por GMM en 3D
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_test_3d[:, 0], X_test_3d[:, 1], X_test_3d[:, 2], c=gmm_labels_test, cmap='viridis', s=50)
legend1 = ax.legend(*scatter.legend_elements(), title="Cluster")
ax.add_artist(legend1)
ax.set_title('Clusters generados por GMM en 3D')
ax.set_xlabel('UMAP Component 1')
ax.set_ylabel('UMAP Component 2')
ax.set_zlabel('UMAP Component 3')
plt.show()

# Graficar los clusters generados por Deep SVDD en 3D
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_test_3d[:, 0], X_test_3d[:, 1], X_test_3d[:, 2], c=svdd_labels_test, cmap='viridis', s=50)
legend1 = ax.legend(*scatter.legend_elements(), title="Cluster")
ax.add_artist(legend1)
ax.set_title('Clusters generados por Deep SVDD en 3D')
ax.set_xlabel('UMAP Component 1')
ax.set_ylabel('UMAP Component 2')
ax.set_zlabel('UMAP Component 3')
plt.show()
# Out:
# c:\anaconda3\envs\inteligencia\Lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
